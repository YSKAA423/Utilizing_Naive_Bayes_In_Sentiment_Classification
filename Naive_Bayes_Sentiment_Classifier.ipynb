# %% [markdown]
# # This portfolio project is part of the AI/ML Engineering career path provided by Codecademy and aims to practically apply end-to-end machine learning (ML) workflow steps . It particularly aims to utilize Naive bayes (using bayes theorem) in classifying sentiment.
# -------------------
#
# ## Project goals:
#     > Applying the famous probability theorem `bayes theorem` through the `Naive Bayes` model in order to calculate the probabilty of a text falling into specific sentiment classes.
#     > Showcase a general end-to-end machine learning workflow.
#     > Build pipelines for effieciency, reproducability, and generalizabilty of the ML workflow.

# %% [markdown]
# ----
# ## General Workflow (Iterative):
#
# 1. **Extract, Transform, Load (ETL):** Import and prepare the dataset (e.g., from CSV or web source).
# 2. **Basic Preprocessing:** Handle null values, remove duplicates, encode labels.
# 3. **Train-Test-Validation Split:** Separate the data for training, tuning, and final evaluation.
# 4. **Exploratory Data Analysis (EDA):** Analyze label distribution, text lengths, frequent tokens, and other insights.
# 5. **Feature Engineering:** Convert raw text into features using methods like `CountVectorizer`, including potential bigrams or stopword removal.
# 6. **Model Selection:** Choose a suitable model (e.g., `MultinomialNB`) and pipeline approach.
# 7. **Model Evaluation:** Evaluate performance using metrics like accuracy, precision, recall, F1-score, and confusion matrix.
# 8. **Hyperparameter Tuning:** Adjust parameters such as n-gram range, `alpha` (NB smoothing), or vocabulary size.
# 9. **Model Validation:** Ensure model generalizes well using validation data.
# 10. **ML Pipeline Building:** Package preprocessing and model steps into a `Pipeline` for consistent inference (and future deployment).
#
# ---
# ## Since we are dealing with **text classification**, NLP preprocessing steps are required (lowercasing, punctuation removal, etc.), and features will be extracted using `CountVectorizer`. I will begin by performing cleaning, then Basic EDA (e.g. Checking the most and least repeating words or phrases), and proceed to modeling, evaluation, and tuning using a Naive Bayes classifier.
#
# ## The dataset will include the following:
# **target**: the polarity of the tweet (0 = negative, 4 = positive)
#
# **ids**: The id of the tweet (2087)
#
# **date**: the date of the tweet (Sat May 16 23:58:44 UTC 2009)
#
# **flag**: The query (lyx). If there is no query, then this value is NO_QUERY.
#
# **user**: the user that tweeted (robotickilldozr)
#
# **text**: the text of the tweet (Lyx is cool)
#
# Note: The dataset can viewed here: [Dataset](https://www.kaggle.com/datasets/kazanova/sentiment140)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("./training.1600000.processed.noemoticon.csv", encoding='latin-1', header=None)
df.columns = ['target', 'ids', 'date', 'flag', 'user', 'text']
df = df[['text', 'target']]  # Will include the text and the sentiment of that text
df['target'] = df['target'].map({0: 0, 4: 1}) #Mapping the sentiments into 0, and 1 
df = df.sample(n=100000, random_state=42).reset_index(drop=True) # Will sample 20000 from the original 1.6 million rows

# %% [markdown]
# ## Getting to know the dataset

# %%
# A look into the dataframe
df.head()
# Out:
#                                                 text  target
# 0             @chrishasboobs AHHH I HOPE YOUR OK!!!        0
# 1  @misstoriblack cool , i have no tweet apps  fo...       0
# 2  @TiannaChaos i know  just family drama. its la...       0
# 3  School email won't open  and I have geography ...       0
# 4                             upper airways problem        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   text    100000 non-null  object
#  1   target  100000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 1.5+ MB

# %%
# The target vaariables in place
df.target.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.target.value_counts() # Very similar class distribution - No to Little class imbalance
# Out:
# target
# 1    50057
# 0    49943
# Name: count, dtype: int64

# %% [markdown]
# ## Preprocessing steps

# %%
# Any null fields?
df.isna().any()
# Out:
# text      False
# target    False
# dtype: bool

# %%
# Are there duplicated rows?
df.duplicated().any()
# Out:
# True

# %%
# Dropping duplicates
df = df.drop_duplicates()

# %%
df.target.value_counts()
# Out:
# target
# 1    49954
# 0    49771
# Name: count, dtype: int64

# %% [markdown]
# ### Splitting the dataset before proceeding with text preprocessing (85% Training set, 15% Testing set)

# %%
x = df['text']
y = df['target']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y , test_size = 0.15, random_state = 42)

# %% [markdown]
# ## Basic Text Processing and EDA
#
#     > As the dataset contains punctuations, mentions  targeting other users, and special characters they will be removed. Additionally, all words will be lowercased to avoid missing up vocabulary needed (e.g. "data!" will not be considered the same as "data")
# Note: You can view this article for many techniques: [Article](https://www.analyticsvidhya.com/blog/2022/01/text-cleaning-methods-in-nlp/)

# %%
import re
import string
from sklearn.preprocessing import FunctionTransformer 
from Text_Preprocessing import remove_mentions, remove_punctuations, lower_case_remove_whitespace, remove_non_ascii ,punctuations, mention_pattern

# %% [markdown]
# ### Some unit tests for the text preprocessing functions built in the Text_Preprocessing.py file will be conducted below

# %%
# !python -m unittest -v Unit_Tests
# Out:
# test_lower_case_remove_whitespace (Unit_Tests.test_text_preprocessing.test_lower_case_remove_whitespace) ... ok
# test_remove_mentions (Unit_Tests.test_text_preprocessing.test_remove_mentions) ... ok
# test_remove_non_ascii (Unit_Tests.test_text_preprocessing.test_remove_non_ascii) ... ok
# test_remove_punctuations (Unit_Tests.test_text_preprocessing.test_remove_punctuations) ... ok
#
# ----------------------------------------------------------------------
# Ran 4 tests in 0.002s
#
# OK

# %%
from sklearn.pipeline import Pipeline

# %%
# Wrapping them in the FunctiopnTransformer in order to use them within pipelines
mention_remover = FunctionTransformer(remove_mentions, validate=False)
punctuation_remover = FunctionTransformer(remove_punctuations, validate=False)
lowercaser = FunctionTransformer(lower_case_remove_whitespace, validate=False)
ascii_cleaner = FunctionTransformer(remove_non_ascii, validate=False)

# Building the text preprocessing pipeline
text_preprocessing_pipeline = Pipeline([('remove_mentions', mention_remover),
                                        ('remove_punctuations', punctuation_remover),
                                        ('lowercase_strip', lowercaser),
                                       ('remove_ascii_characters', ascii_cleaner)])

# %%
x_train_preprocessed = text_preprocessing_pipeline.fit_transform(x_train) # An exmaple dataframe to showcase the difference against the original first 5 rows

# %%
x_train_preprocessed = pd.DataFrame(x_train_preprocessed, columns = ["text"])

# %%
x_train_preprocessed.head()
# Out:
#                                                     text
# 66729                                      ps i miss you
# 16589    oops i mean later on since its after 12 already
# 53665        my so knows more about basketball than i do
# 23198  silicone sucks we must always support ori bro ...
# 15765  the rest of us understand our real blessings l...

# %% [markdown]
# ### We will show the most commonly used single words and 2 word phrases alongside the least ones as part of a simple `textual EDA`.
#
# ### `CountVectorizer()` which is part of the preprocessing module of sklearn will be used to make a dictionary of words and their respective counts. The CountVectorizer() and many other techniques could fall into the `feature engineering` aspect as we provied the model with that dictionary (vocabulary) in order to train and then be evaluated and tuned.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Building the pipelines needed
word_pipeline = Pipeline([('text_preprocess', text_preprocessing_pipeline),
                          ('vectorizer', CountVectorizer())])

two_words_pipeline = Pipeline([('text_preprocess', text_preprocessing_pipeline),
                          ('vectorizer', CountVectorizer(ngram_range = (2,2)))])

# %%
word_pipeline.fit(x_train)
two_words_pipeline.fit(x_train)
# Out:
# Pipeline(steps=[('text_preprocess',
#                  Pipeline(steps=[('remove_mentions',
#                                   FunctionTransformer(func=<function remove_mentions at 0x0000027A07723F60>)),
#                                  ('remove_punctuations',
#                                   FunctionTransformer(func=<function remove_punctuations at 0x0000027A07723EC0>)),
#                                  ('lowercase_strip',
#                                   FunctionTransformer(func=<function lower_case_remove_whitespace at 0x0000027A07723E20>)),
#                                  ('remove_ascii_characters',
#                                   FunctionTransformer(func=<function remove_non_ascii at 0x0000027A07723D80>))])),
#                 ('vectorizer', CountVectorizer(ngram_range=(2, 2)))])

# %%
# Showcasing the dictionary 
w_vectorizer = word_pipeline.named_steps["vectorizer"]
w_vectorizer.vocabulary_
# Out:
# {'ps': 44756,
#  'miss': 37173,
#  'you': 63798,
#  'oops': 41056,
#  'mean': 36164,
#  'later': 33143,
#  'on': 40842,
#  'since': 51319,
#  'its': 30630,
#  'after': 2656,
#  '12': 244,
#  'already': 3383,
#  'my': 38445,
#  'so': 52169,
#  'knows': 32513,
#  'more': 37717,
#  'about': 2133,
#  'basketball': 5963,
#  'than': 55805,
#  'do': 15353,
#  'silicone': 51255,
#  'sucks': 54116,
#  'we': 61077,
#  'must': 38380,
#  'always': 3445,
#  'support': 54495,
#  'ori': 41248,
#  'bro': 8439,
#  'wah': 60602,
#  'mine': 37014,
#  'lasts': 33116,
#  'for': 19860,
#  'year': 63475,
#  'nia': 39273,
#  'the': 55918,
#  'rest': 47906,
#  'of': 40442,
#  'us': 59625,
#  'understand': 59142,
#  'our': 41376,
#  'real': 46985,
#  'blessings': 7273,
#  'lie': 33709,
#  'in': 29686,
#  'friends': 20317,
#  'family': 18433,
#  'and': 3740,
#  'love': 34587,
#  'listening': 33989,
#  'to': 56881,
#  'shinees': 50701,
#  '2nd': 929,
#  'mini': 37040,
#  'album': 3112,
#  'quotromeoquot': 46148,
#  'noooooo': 39762,
#  'poor': 43799,
#  'cows': 12707,
#  'come': 11720,
#  'droops': 16009,
#  'amp': 3604,
#  'drink': 15949,
#  'me': 36148,
#  'when': 61646,
#  'youre': 63862,
#  'home': 24665,
#  'hordawn': 24886,
#  'missed': 37179,
#  'ui': 58942,
#  'was': 60874,
#  'all': 3225,
#  'alone': 3341,
#  'bored': 7832,
#  'had': 22947,
#  'talk': 55087,
#  'klass': 32400,
#  'cuz': 13371,
#  'didnt': 14830,
#  'have': 23574,
#  'lol': 34236,
#  'oh': 40541,
#  'yes': 63584,
#  'is': 30450,
#  'wonderful': 62323,
#  'friend': 20299,
#  'hope': 24851,
#  'following': 19746,
#  'her': 24060,
#  'too': 57284,
#  'omg': 40788,
#  'amazing': 3491,
#  'ive': 30696,
#  'favourited': 18669,
#  'it': 30544,
#  'pain': 41812,
#  'good': 21875,
#  'afternoon': 2665,
#  'everyone': 17764,
#  'think': 56175,
#  'taylor': 55316,
#  'laughtner': 33203,
#  'selena': 50081,
#  'gomez': 21840,
#  'are': 4331,
#  'cutest': 13343,
#  'couple': 12628,
#  'them': 55961,
#  'both': 7930,
#  'just': 31641,
#  'read': 46950,
#  'fave': 18646,
#  'mag': 35232,
#  'no': 39599,
#  'worries': 62624,
#  'watching': 60935,
#  'madtv': 35221,
#  'reminds': 47621,
#  '6th': 1613,
#  'grade': 22155,
#  'bed': 6320,
#  'how': 25106,
#  'matthew': 35940,
#  'behind': 6483,
#  'vehicle': 59974,
#  'with': 62154,
#  'ron': 48587,
#  'paul': 42290,
#  'bumper': 8883,
#  'sticker': 53521,
#  'pull': 44882,
#  'over': 41520,
#  'recommended': 47181,
#  'he': 23674,
#  'doogie': 15613,
#  'great': 22314,
#  'guys': 22802,
#  'httpcligs7qgpb7': 26062,
#  'tell': 55525,
#  'contacts': 12213,
#  'pics': 43055,
#  'deleted': 14313,
#  'ate': 4775,
#  'grape': 22248,
#  'jizzed': 31233,
#  'pants': 41964,
#  'am': 3457,
#  'gonna': 21862,
#  'see': 49990,
#  'wait': 60644,
#  'guess': 22665,
#  'that': 55866,
#  'countdown': 12602,
#  'has': 23496,
#  'passed': 42173,
#  'going': 21798,
#  'but': 9015,
#  'ride': 48198,
#  'jonas': 31383,
#  'brothers': 8531,
#  'feels': 18833,
#  'headache': 23682,
#  'coming': 11766,
#  'means': 36180,
#  'ill': 29461,
#  'turn': 58177,
#  'down': 15742,
#  'music': 38344,
#  'quotsimplyquot': 46218,
#  'juices': 31542,
#  'sale': 49196,
#  '400': 1202,
#  'here': 24073,
#  'bought': 7959,
#  'bunch': 8894,
#  'would': 62669,
#  'be': 6155,
#  'fun': 20575,
#  'heard': 23760,
#  'stories': 53679,
#  'lil': 33830,
#  'ones': 40888,
#  'meet': 36297,
#  'em': 16958,
#  'enjoy': 17220,
#  'trip': 57889,
#  'safe': 49116,
#  'travels': 57761,
#  'mostly': 37864,
#  'quotemilyyou': 45562,
#  'areawesomei': 4339,
#  'will': 61978,
#  'say': 49496,
#  'thati': 55887,
#  'thatphonecallquot': 55898,
#  'psst': 44788,
#  'what': 61578,
#  'launching': 33208,
#  'thursday': 56448,
#  'httpsnurlcomj4yov': 26884,
#  'please': 43452,
#  'spread': 53042,
#  'word': 62455,
#  'via': 60108,
#  'exactly': 17863,
#  'luck': 34831,
#  'tomorrow': 57135,
#  'major': 35358,
#  'goes': 21782,
#  'well': 61383,
#  'this': 56218,
#  'sencha': 50162,
#  'missing': 37187,
#  'something': 52374,
#  'genmai': 21202,
#  'tastes': 55256,
#  'better': 6745,
#  'isnt': 30499,
#  'usual': 59689,
#  'lalalallalalalalalallaa': 32944,
#  'throat': 56365,
#  'swolen': 54839,
#  'cant': 9533,
#  'even': 17688,
#  'swallow': 54690,
#  'sad': 49061,
#  'metaphysical': 36647,
#  'store': 53670,
#  'closed': 11323,
#  'headin': 23714,
#  'out': 41381,
#  'wish': 62126,
#  'txt': 58737,
#  'celly': 10091,
#  'if': 29360,
#  'goin': 21796,
#  'bf': 6796,
#  'much': 38163,
#  'yeah': 63434,
#  'right': 48229,
#  'agreed': 2832,
#  'followfriday': 19741,
#  'because': 6296,
#  'shes': 50651,
#  'twitter': 58540,
#  'people': 42572,
#  'trying': 58027,
#  'many': 35616,
#  'platforms': 43385,
#  'can': 9441,
#  'communicate': 11827,
#  'nice': 39289,
#  'person': 42711,
#  'dont': 15586,
#  'lose': 34500,
#  'argh': 4372,
#  'find': 19175,
#  'phone': 42909,
#  'called': 9329,
#  'thousand': 56323,
#  'times': 56626,
#  'realized': 47002,
#  'silent': 51253,
#  'searching': 49907,
#  'high': 24270,
#  'low': 34671,
#  'mixed': 37263,
#  'up': 59449,
#  'flights': 19515,
#  'bc': 6113,
#  'tried': 57861,
#  'book': 7698,
#  'while': 61698,
#  'not': 39892,
#  'smart': 51897,
#  'want': 60796,
#  'really': 47019,
#  'awesome': 5144,
#  'vintage': 60239,
#  'shirt': 50735,
#  'saw': 49482,
#  'pretty': 44342,
#  'jocorequests': 31295,
#  'feel': 18809,
#  'fantastic': 18500,
#  'need': 38924,
#  'reminded': 47616,
#  'worry': 62629,
#  'dead': 14010,
#  'lions': 33952,
#  'now': 39992,
#  'could': 12578,
#  'only': 40930,
#  'put': 45010,
#  'together': 57033,
#  'ftw': 20487,
#  'ignore': 29389,
#  'those': 56287,
#  'children': 10656,
#  'learn': 33349,
#  'without': 62174,
#  'doing': 15452,
#  'parent': 42047,
#  'open': 41075,
#  'public': 44826,
#  'time': 56589,
#  'interested': 30161,
#  'drop': 16010,
#  'by': 9134,
#  'why': 61861,
#  'get': 21281,
#  'early': 16407,
#  'morning': 37758,
#  'sunday': 54314,
#  'go': 21714,
#  'work': 62474,
#  'formula1': 19953,
#  'trex': 57831,
#  'httpblipfm7fbc2': 25981,
#  'refuse': 47390,
#  'give': 21533,
#  'til': 56566,
#  'realize': 47001,
#  'got': 22071,
#  'sum': 54218,
#  'mass': 35845,
#  'solidiers': 52306,
#  'whod': 61772,
#  'anything': 4061,
#  'stop': 53654,
#  'their': 55953,
#  'workplace': 62563,
#  'sure': 54528,
#  'wear': 61090,
#  'party': 42133,
#  'clothes': 11343,
#  'hair': 23095,
#  'checked': 10426,
#  'story': 53693,
#  'still': 53543,
#  'online': 40919,
#  'presstv': 44318,
#  'site': 51438,
#  'im': 29515,
#  'besides': 6673,
#  'uhm': 58925,
#  'kitty': 32369,
#  'ran': 46748,
#  'awayyesterday': 5127,
#  'worried': 62622,
#  'aww': 5218,
#  'knew': 32453,
#  'soon': 52479,
#  'e4': 16367,
#  'thought': 56309,
#  'few': 18960,
#  'days': 13912,
#  'wednesday': 61185,
#  'scholl': 49662,
#  'unhappy': 59243,
#  'air': 2989,
#  'pick': 43036,
#  'quite': 45257,
#  'excited': 17930,
#  'though': 56291,
#  'baby': 5395,
#  'yet': 63649,
#  'due': 16156,
#  'today': 56923,
#  'waiting': 60655,
#  'getting': 21301,
#  'ready': 46972,
#  'wedding': 61170,
#  'boyfriend': 8027,
#  'hate': 23528,
#  'lovely': 34623,
#  'hand': 23237,
#  'marks': 35726,
#  'back': 5454,
#  'from': 20404,
#  'apply': 4213,
#  'own': 41651,
#  'suncream': 54310,
#  'hot': 24980,
#  'boy6': 8019,
#  'sleeps': 51724,
#  'working': 62518,
#  'custom': 13313,
#  'cms': 11416,
#  'skeedio': 51501,
#  'tiring': 56774,
#  'ur': 59584,
#  'welcomei': 61369,
#  'liked': 33811,
#  'multiple': 38250,
#  'acct': 2273,
#  'option': 41157,
#  'garage': 20959,
#  'garbage': 20963,
#  'day': 13825,
#  'woohoo': 62373,
#  'take': 55041,
#  'away': 5110,
#  'httptwitpiccom6gizn': 27994,
#  'braceless': 8073,
#  'aw': 5063,
#  'makes': 35382,
#  'happy': 23377,
#  'haha': 22973,
#  'xd': 63138,
#  'look': 34392,
#  'there': 56029,
#  'although': 3429,
#  'dog': 15415,
#  'fred': 20149,
#  'finally': 19151,
#  'hubby': 28869,
#  'snore': 52132,
#  'sound': 52638,
#  'chinese': 10718,
#  'as': 4553,
#  'feeling': 18816,
#  'nervous': 39060,
#  'rapidshare': 46801,
#  'one': 40857,
#  'tough': 57493,
#  'nut': 40195,
#  'anyone': 4055,
#  'help': 24006,
#  'maybe': 36003,
#  'next': 39211,
#  'should': 50915,
#  'try': 58022,
#  'catch': 9896,
#  'ball': 5681,
#  'glove': 21646,
#  'other': 41324,
#  'ouch': 41353,
#  'freaking': 20137,
#  'studying': 53906,
#  'sejarah': 50067,
#  'imissyouuu': 29564,
#  'lt3': 34722,
#  'ohh': 40559,
#  'bladdy': 7161,
#  'watch': 60924,
#  'movie': 37981,
#  'she': 50585,
#  'did': 14822,
#  'kahit': 31727,
#  'umuulan': 59046,
#  'smile': 51941,
#  'face': 18266,
#  'seen': 50029,
#  'unfortunately': 59223,
#  'brought': 8537,
#  'camera': 9393,
#  'woke': 62275,
#  'miserably': 37145,
#  'sick': 51104,
#  'thanks': 55824,
#  'hug': 28889,
#  'monday': 37537,
#  'ha': 22876,
#  'know': 32494,
#  'thia': 56114,
#  'till': 56574,
#  'camping': 9429,
#  'tonight': 57203,
#  'yeahkris': 63449,
#  'allen': 3245,
#  'where': 61658,
#  'liveits': 34044,
#  'crazy': 12863,
#  'hee': 23855,
#  'prefer': 44193,
#  'genfriendship': 21193,
#  'creeps': 12930,
#  'picturing': 43070,
#  'spock': 52971,
#  'being': 6494,
#  'immaculate': 29570,
#  'sneezing': 52085,
#  'every': 17743,
#  '15sec': 408,
#  'allergies': 3253,
#  'full': 20556,
#  'force': 19867,
#  'very': 60071,
#  'ephie': 17356,
#  'at': 4761,
#  'moment': 37482,
#  'allergy': 3256,
#  'meds': 36262,
#  'bueno': 8763,
#  'blackberry': 7134,
#  'troubles': 57958,
#  'fortunately': 19981,
#  'enough': 17246,
#  'htc': 25174,
#  'touch': 57481,
#  'works': 62566,
#  'fine': 19182,
#  'almost': 3333,
#  'years': 63490,
#  'ahhh': 2902,
#  'wawa': 61011,
#  'some': 52336,
#  'diet': 14860,
#  'lemonade': 33493,
#  'tea': 55357,
#  'shoulders': 50921,
#  'sore': 52559,
#  'carrying': 9788,
#  'bowling': 7997,
#  'backpackstill': 5499,
#  'walk': 60695,
#  'car': 9623,
#  'any': 4030,
#  'pro': 44461,
#  'life': 33730,
#  'youth': 63884,
#  'groups': 22521,
#  'philippines': 42877,
#  'let': 33566,
#  'hook': 24808,
#  'contact': 12209,
#  'httptwitpiccom2vzw6': 27449,
#  'whos': 61843,
#  'half': 23141,
#  'naked': 38621,
#  'again': 2700,
#  'okay': 40634,
#  'yeahits': 63448,
#  'power': 44043,
#  'youtube': 63892,
#  'looked': 34398,
#  'wrote': 62811,
#  'buon': 8915,
#  'gionro': 21456,
#  'typo': 58779,
#  'honestly': 24771,
#  'spell': 52849,
#  'giorno': 21458,
#  'sue': 54146,
#  'holiday': 24622,
#  'weekend': 61233,
#  'layn': 33273,
#  'dwn': 16318,
#  'mommy': 37512,
#  'deciding': 14109,
#  'shall': 50461,
#  'start': 53332,
#  'made': 35189,
#  'imafat13yroldg': 29522,
#  'tweeted': 58302,
#  'thank': 55811,
#  'donny': 15581,
#  'sid': 51157,
#  'might': 36851,
#  'girlfriend': 21473,
#  'doesnt': 15411,
#  'does': 15409,
#  'then': 55986,
#  'serious': 50280,
#  'or': 41171,
#  'last': 33102,
#  'long': 34354,
#  'michael': 36748,
#  'hasnt': 23506,
#  'replied': 47728,
#  'sd': 49864,
#  'accoustic': 2270,
#  'show': 50942,
#  'coulda': 12579,
#  'been': 6405,
#  'kill': 32213,
#  'tweeting': 58335,
#  'sleep': 51682,
#  'mcorgies': 36124,
#  'entertaining': 17285,
#  'weee': 61204,
#  'hey': 24189,
#  'wales': 60692,
#  'sometime': 52385,
#  'these': 56082,
#  'stupid': 53960,
#  'exams': 17884,
#  'busy': 9008,
#  'writing': 62785,
#  'flew': 19487,
#  'cuckoos': 13171,
#  'nest': 39077,
#  'write': 62773,
#  'outside': 41460,
#  'cry': 13103,
#  'farmyard': 18544,
#  'wont': 62344,
#  'around': 4446,
#  'lighter': 33781,
#  'kind': 32264,
#  'awkward': 5193,
#  'like': 33808,
#  'your': 63860,
#  'exam': 17869,
#  'goodnight': 21928,
#  'nyc': 40240,
#  'httpbitlyaivit': 25423,
#  'whole': 61779,
#  'pusiiing': 45002,
#  'birthday': 7023,
#  'upload': 59508,
#  'picture': 43062,
#  'tweet': 58287,
#  'hearts': 23792,
#  'content': 12232,
#  'sweetie': 54761,
#  'xx': 63212,
#  'tired': 56728,
#  'easily': 16455,
#  'lately': 33130,
#  'wake': 60674,
#  'awake': 5075,
#  'hours': 25033,
#  'sleeping': 51701,
#  'condo': 12011,
#  'montrose': 37645,
#  'alright': 3396,
#  'stayed': 53407,
#  '3am': 1129,
#  'reading': 46962,
#  'finishing': 19223,
#  'shame': 50467,
#  'seeing': 50013,
#  'letting': 33593,
#  'photo': 42941,
#  'eminem': 17030,
#  'thing': 56139,
#  'sooooooo': 52514,
#  'disrespectful': 15183,
#  'mad': 35164,
#  'ughh': 58883,
#  'anywho': 4091,
#  'twilight': 58445,
#  'yey': 63668,
#  'new': 39143,
#  'moon': 37668,
#  'whered': 61661,
#  'hear': 23759,
#  'nigga': 39369,
#  'gotta': 22086,
#  '530': 1431,
#  'kingda': 32286,
#  'ka': 31695,
#  'ltltthat': 34781,
#  'cool': 12339,
#  'whip': 61717,
#  'lone': 34341,
#  'soldier': 52292,
#  'aha': 2858,
#  'thats': 55902,
#  'taking': 55059,
#  'battles': 6027,
#  'shit': 50751,
#  'spare': 52762,
#  'drama': 15846,
#  'loving': 34660,
#  'weather': 61099,
#  'were': 61481,
#  'having': 23593,
#  'bbq': 6095,
#  'evening': 17689,
#  'apparently': 4167,
#  'download': 15763,
#  'forced': 19868,
#  'question': 45202,
#  'blog': 7345,
#  'post': 43942,
#  'nobody': 39612,
#  'ever': 17712,
#  'buys': 9101,
#  'flowers': 19595,
#  'telegraph': 55505,
#  'quothow': 45759,
#  'use': 59640,
#  'twitterquot': 58635,
#  'advice': 2574,
#  'newspaper': 39189,
#  'havnt': 23597,
#  'revised': 48055,
#  'dayamphave': 13830,
#  'hour': 25025,
#  'english': 17200,
#  'lit': 34004,
#  'mnday': 37352,
#  'changed': 10265,
#  'username': 59651,
#  'follow': 19717,
#  'office': 40478,
#  'wanna': 60782,
#  'badly': 5551,
#  'cavs': 9967,
#  'sympathy': 54893,
#  'needed': 38927,
#  'done': 15541,
#  'talking': 55094,
#  'tornado': 57414,
#  'buffalo': 8767,
#  'grove': 22526,
#  'area': 4332,
#  'yay': 63371,
#  'picked': 43037,
#  'such': 54072,
#  'silly': 51262,
#  'handing': 23255,
#  'coffee': 11521,
#  'bosscow': 7912,
#  'they': 56094,
#  'offer': 40466,
#  'platters': 43392,
#  'old': 40711,
#  'tbs': 55339,
#  'vs': 60481,
#  'vote': 60447,
#  'blink': 7298,
#  'letcha': 33567,
#  'september': 50233,
#  'signed': 51220,
#  'myself': 38480,
#  'wwwruckucom': 63029,
#  'busted': 9001,
#  '7th': 1717,
#  'placesuckie': 43323,
#  'keeps': 31980,
#  'reception': 47125,
#  'ougi': 41368,
#  'atbasicdesignclass': 4771,
#  'class': 11163,
#  'teacher': 55361,
#  'cute': 13329,
#  'man': 35477,
#  'mb': 36038,
#  'believe': 6525,
#  'wouw': 62691,
#  'girl': 21468,
#  'wore': 62473,
#  'heels': 23883,
#  '11am': 229,
#  '7pm': 1712,
#  'came': 9383,
#  'soak': 52175,
#  'feets': 18842,
#  'who': 61762,
#  'wana': 60756,
#  'rub': 48804,
#  'bummer': 8873,
#  'noah': 39605,
#  'camp': 9414,
#  'yearemp': 63479,
#  'week': 61224,
#  'nana': 38662,
#  'kicks': 32169,
#  'quick': 45218,
#  'todaytomorrow': 56990,
#  'wifey': 61925,
#  'unsure': 59404,
#  'off': 40447,
#  'none': 39701,
#  'team': 55377,
#  'small': 51887,
#  'chance': 10250,
#  'academy': 2205,
#  'wooo': 62387,
#  '27th': 802,
#  'august': 4928,
#  'hi': 24236,
#  'fi': 18991,
#  'wee': 61197,
#  'once': 40851,
#  'proof': 44644,
#  'second': 49951,
#  'shipping': 50724,
#  'tracking': 57584,
#  'number': 40158,
#  'ocd': 40385,
#  'damm': 13566,
#  'bb': 6072,
#  'fool': 19811,
#  'itoh': 30624,
#  'trynna': 58033,
#  'job': 31269,
#  'thursdayi': 56450,
#  'cherry': 10553,
#  'culture': 13210,
#  'order': 41201,
#  'arrived': 4484,
#  'pay': 42330,
#  '1212': 256,
#  'customs': 13326,
#  'charge': 10328,
#  'double': 15707,
#  'exposurecute': 18124,
#  'football': 19842,
#  'season': 49916,
#  'misses': 37182,
#  'sis': 51403,
#  'df': 14736,
#  'cs': 13123,
#  'wat': 60922,
#  'darling': 13723,
#  'paulina': 42294,
#  'hella': 23956,
#  'loose': 34469,
#  'piece': 43078,
#  'glass': 21584,
#  'foot': 19840,
#  'hardware': 23429,
#  'headheadache': 23713,
#  'w00t': 60519,
#  'method': 36657,
#  'bit': 7059,
#  'tricky': 57860,
#  'pi': 43010,
#  'root2': 48647,
#  'which': 61687,
#  '111072cm': 194,
#  'night': 39379,
#  'funny': 20647,
#  'making': 35390,
#  'afd': 2614,
#  'easier': 16450,
#  'moneys': 37562,
#  'carlton': 9713,
#  'two': 58700,
#  'asians': 4615,
#  'backseat': 5509,
#  'mexicans': 36694,
#  'hahahahaha': 23001,
#  'kt': 32698,
#  'hates': 23540,
#  'sign': 51215,
#  'pink': 43167,
#  'tattoed': 55276,
#  'rrrr': 48782,
#  'answer': 3941,
#  'tom': 57086,
#  'gig': 21391,
#  'bike': 6930,
#  'experts': 18075,
#  'buy': 9090,
#  'son': 52412,
#  'idea': 29292,
#  '500': 1375,
#  'curve': 13295,
#  'rip': 48296,
#  'shawty': 50577,
#  'macki': 35145,
#  'listen': 33983,
#  'songs': 52431,
#  'wo': 62247,
#  'crying': 13107,
#  'chills': 10703,
#  'flowing': 19599,
#  'river': 48335,
#  'backor': 5495,
#  'downtown': 15790,
#  'wking': 62209,
#  'event': 17701,
#  'ink': 29962,
#  'downt': 15788,
#  'street': 53774,
#  'jeez': 31006,
#  'usually': 59691,
#  'dad': 13469,
#  'walks': 60713,
#  'asks': 4629,
#  'mum': 38265,
#  'stomach': 53629,
#  'theyre': 56101,
#  'fighting': 19051,
#  'sarcastic': 49378,
#  'dissing': 15204,
#  'fisicmath': 19321,
#  'homework': 24732,
#  'boring': 7875,
#  'mug': 38210,
#  'greene': 22364,
#  'damn': 13573,
#  'call': 9322,
#  'schedule': 49632,
#  'course': 12644,
#  'lupes': 34934,
#  'songsucks': 52438,
#  'leaked': 33333,
#  'rapif': 46802,
#  'philosophy': 42889,
#  'kinda': 32265,
#  'running': 48896,
#  'hassles': 23514,
#  'systems': 54925,
#  'heres': 24110,
#  'weight': 61335,
#  '1365': 341,
#  'artist': 4532,
#  'date': 13768,
#  'studio': 53897,
#  'archery': 4311,
#  'soaked': 52176,
#  'shower': 50957,
#  'triple': 57893,
#  'eating': 16490,
#  'peanut': 42411,
#  'butter': 9043,
#  'toast': 56885,
#  'charli': 10344,
#  'hes': 24167,
#  'seed': 49992,
#  'hold': 24610,
#  'onto': 40969,
#  'feeeeelin': 18802,
#  'tweeteryay': 58312,
#  'yoyo': 63941,
#  'marcus': 35654,
#  'nasty': 38756,
#  'silva': 51264,
#  'ease': 16446,
#  'an': 3694,
#  'aquarium': 4284,
#  'commercial': 11799,
#  'planned': 43348,
#  'leave': 33371,
#  'used': 59642,
#  'peeling': 42466,
#  'winter': 62092,
#  'particularly': 42113,
#  '30': 981,
#  'halter': 23186,
#  'monitor': 37578,
#  'doh': 15442,
#  'herman': 24131,
#  'miller': 36948,
#  'embody': 17002,
#  'chair': 10203,
#  'months': 37629,
#  'ago': 2813,
#  'costs': 12544,
#  '40': 1201,
#  'less': 33558,
#  'wife': 61921,
#  'wholl': 61784,
#  'also': 3413,
#  'roots': 48652,
#  'bebes': 6282,
#  'kids': 32193,
#  'fall': 18402,
#  'asleep': 4633,
#  'remember': 47604,
#  'watched': 60926,
#  'vhs': 60106,
#  'broke': 8473,
#  'london': 34337,
#  'dev': 14677,
#  'awesomeness': 5157,
#  'expectin': 18046,
#  'groovin': 22497,
#  'tune': 58149,
#  'mr': 38051,
#  'strout': 53850,
#  'ni': 39272,
#  'results': 47950,
#  'ian': 29210,
#  'parsley': 42091,
#  'sending': 50167,
#  'bigotted': 6916,
#  'numpties': 40175,
#  'strasbourg': 53742,
#  'left': 33418,
#  'starbucks': 53295,
#  'john': 31322,
#  'possibly': 43940,
#  'interviews': 30232,
#  'gosh': 22050,
#  'sooo': 52503,
#  'vou': 60457,
#  'sair': 49167,
#  'bjs': 7114,
#  'sixty': 51467,
#  'six': 51461,
#  'holy': 24659,
#  'picnic': 43049,
#  'went': 61469,
#  'cruiselolu': 13065,
#  'facetime': 18295,
#  'missy': 37211,
#  'heeheee': 23876,
#  'nicealcoholism': 39290,
#  'learned': 33351,
#  'forget': 19916,
#  'photos': 42966,
#  'lost': 34517,
#  'mm': 37305,
#  ...}

# %%
# Showcasing the dictionary 
tw_vectorizer = two_words_pipeline.named_steps["vectorizer"]
tw_vectorizer.vocabulary_
# Out:
# {'ps miss': 261476,
#  'miss you': 207052,
#  'oops mean': 242380,
#  'mean later': 202647,
#  'later on': 182898,
#  'on since': 239747,
#  'since its': 288707,
#  'its after': 170620,
#  'after 12': 9054,
#  '12 already': 783,
#  'my so': 218112,
#  'so knows': 293091,
#  'knows more': 180389,
#  'more about': 209881,
#  'about basketball': 6051,
#  'basketball than': 37497,
#  'than do': 314213,
#  'silicone sucks': 288261,
#  'sucks we': 306575,
#  'we must': 364282,
#  'must always': 214490,
#  'always support': 14973,
#  'support ori': 308521,
#  'ori bro': 243890,
#  'bro wah': 52515,
#  'wah mine': 358352,
#  'mine lasts': 205962,
#  'lasts for': 182542,
#  'for year': 114542,
#  'year nia': 383290,
#  'the rest': 322786,
#  'rest of': 271482,
#  'of us': 234818,
#  'us understand': 354463,
#  'understand our': 350993,
#  'our real': 245017,
#  'real blessings': 267400,
#  'blessings lie': 47228,
#  'lie in': 185873,
#  'in friends': 161049,
#  'friends family': 116992,
#  'family and': 103244,
#  'and love': 20793,
#  'listening to': 188768,
#  'to shinees': 338215,
#  'shinees 2nd': 285017,
#  '2nd mini': 2938,
#  'mini album': 206090,
#  'album quotromeoquot': 11967,
#  'noooooo poor': 227724,
#  'poor cows': 257063,
#  'cows come': 73915,
#  'come to': 68911,
#  'to droops': 336042,
#  'droops amp': 91402,
#  'amp drink': 16681,
#  'drink me': 90948,
#  'me when': 202444,
#  'when youre': 369626,
#  'youre home': 388735,
#  'home hordawn': 149674,
#  'missed ui': 207233,
#  'ui was': 350353,
#  'was all': 360338,
#  'all alone': 12330,
#  'alone bored': 13632,
#  'bored had': 49465,
#  'had to': 134940,
#  'to talk': 338587,
#  'talk to': 311346,
#  'to klass': 336905,
#  'klass cuz': 179489,
#  'cuz didnt': 76866,
#  'didnt have': 84165,
#  'have lol': 140228,
#  'oh yes': 236385,
#  'yes is': 383923,
#  'is wonderful': 168179,
#  'wonderful friend': 376551,
#  'friend of': 116792,
#  'of mine': 233701,
#  'mine hope': 205948,
#  'hope youre': 150776,
#  'youre following': 388697,
#  'following her': 111356,
#  'her too': 145200,
#  'omg amazing': 237892,
#  'amazing ive': 15969,
#  'ive favourited': 172032,
#  'favourited it': 104783,
#  'is in': 166876,
#  'in pain': 161878,
#  'pain poor': 247900,
#  'poor me': 257163,
#  'good afternoon': 127468,
#  'afternoon everyone': 9502,
#  'think taylor': 328743,
#  'taylor laughtner': 312087,
#  'laughtner and': 183196,
#  'and selena': 21770,
#  'selena gomez': 281910,
#  'gomez are': 126990,
#  'are the': 27045,
#  'the cutest': 319075,
#  'cutest couple': 76771,
#  'couple love': 73434,
#  'love them': 193889,
#  'them both': 325121,
#  'both just': 50003,
#  'just read': 176324,
#  'read it': 267000,
#  'it on': 169598,
#  'on my': 239360,
#  'my fave': 216034,
#  'fave mag': 104498,
#  'no worries': 227117,
#  'watching madtv': 363036,
#  'madtv it': 196722,
#  'it reminds': 169740,
#  'reminds me': 270471,
#  'me of': 201922,
#  'of 6th': 232117,
#  '6th grade': 4777,
#  'oh bed': 235972,
#  'bed how': 40996,
#  'how love': 152807,
#  'love you': 194007,
#  'you miss': 386091,
#  'miss matthew': 206828,
#  'was just': 360987,
#  'just behind': 175546,
#  'behind vehicle': 42601,
#  'vehicle with': 355882,
#  'with ron': 375206,
#  'ron paul': 274144,
#  'paul bumper': 249972,
#  'bumper sticker': 54288,
#  'sticker didnt': 302423,
#  'didnt pull': 84241,
#  'pull it': 261829,
#  'it over': 169629,
#  'recommended to': 269023,
#  'to he': 336580,
#  'he is': 141975,
#  'is with': 168175,
#  'with doogie': 374193,
#  'doogie both': 89137,
#  'both great': 49984,
#  'great guys': 131274,
#  'guys httpcligs7qgpb7': 133670,
#  'tell me': 312993,
#  'me how': 201629,
#  'how all': 152622,
#  'all my': 12750,
#  'my contacts': 215570,
#  'contacts and': 71149,
#  'and pics': 21321,
#  'pics deleted': 253258,
#  'just ate': 175506,
#  'ate grape': 31446,
#  'grape and': 130898,
#  'and jizzed': 20503,
#  'jizzed in': 173665,
#  'in my': 161719,
#  'my pants': 217423,
#  'oh me': 236162,
#  'me too': 202343,
#  'when am': 369183,
#  'am gonna': 15310,
#  'gonna see': 127355,
#  'see you': 281417,
#  'you oh': 386194,
#  'oh wait': 236328,
#  'wait guess': 358452,
#  'guess that': 132954,
#  'that countdown': 315516,
#  'countdown has': 73266,
#  'has already': 138115,
#  'already passed': 14060,
#  'passed love': 249503,
#  'was going': 360807,
#  'going to': 126811,
#  'to but': 335482,
#  'but my': 55596,
#  'my ride': 217849,
#  'ride is': 272459,
#  'is going': 166669,
#  'to the': 338652,
#  'the jonas': 320797,
#  'jonas brothers': 174480,
#  'feels headache': 105979,
#  'headache coming': 142374,
#  'coming on': 69217,
#  'on that': 239909,
#  'that means': 316136,
#  'means ill': 202838,
#  'ill have': 157883,
#  'have to': 140876,
#  'to turn': 338774,
#  'turn down': 346590,
#  'down my': 89753,
#  'my music': 217204,
#  'all the': 12976,
#  'the quotsimplyquot': 322579,
#  'quotsimplyquot juices': 264742,
#  'juices are': 174942,
#  'are on': 26782,
#  'on sale': 239673,
#  'sale for': 276738,
#  'for 400': 111936,
#  '400 here': 3798,
#  'here bought': 145358,
#  'bought bunch': 50234,
#  'that would': 316973,
#  'would be': 379516,
#  'be fun': 38794,
#  'fun heard': 119718,
#  'heard stories': 142939,
#  'stories about': 303941,
#  'about the': 6648,
#  'the lil': 321047,
#  'lil ones': 188021,
#  'ones would': 241155,
#  'fun to': 119908,
#  'to meet': 337182,
#  'meet em': 203283,
#  'great pics': 131424,
#  'pics enjoy': 253262,
#  'enjoy the': 96710,
#  'the trip': 323991,
#  'trip and': 345168,
#  'and safe': 21690,
#  'safe travels': 276300,
#  'travels but': 344693,
#  'but mostly': 55584,
#  'mostly enjoy': 211750,
#  'quotemilyyou areawesomei': 263844,
#  'areawesomei will': 27219,
#  'will say': 372388,
#  'say thati': 278447,
#  'thati will': 317026,
#  'say thatphonecallquot': 278448,
#  'psst guess': 261590,
#  'guess what': 132975,
#  'what is': 368550,
#  'is launching': 166994,
#  'launching thursday': 183246,
#  'thursday httpsnurlcomj4yov': 332269,
#  'httpsnurlcomj4yov please': 153783,
#  'please spread': 255846,
#  'spread the': 300202,
#  'the word': 324546,
#  'word via': 377311,
#  'good luck': 127899,
#  'luck tomorrow': 195194,
#  'tomorrow major': 340905,
#  'major hope': 197179,
#  'hope all': 150565,
#  'all goes': 12578,
#  'goes well': 126499,
#  'this sencha': 330018,
#  'sencha is': 282147,
#  'is missing': 167154,
#  'missing something': 207474,
#  'something my': 295990,
#  'my genmai': 216260,
#  'genmai tastes': 121989,
#  'tastes better': 311866,
#  'better and': 44262,
#  'and this': 22267,
#  'this isnt': 329646,
#  'isnt usual': 168546,
#  'lalalallalalalalalallaa my': 181568,
#  'my throat': 218402,
#  'throat is': 331681,
#  'is so': 167730,
#  'so swolen': 293512,
#  'swolen cant': 310084,
#  'cant even': 59672,
#  'even swallow': 98590,
#  'is sad': 167603,
#  'sad the': 276004,
#  'the metaphysical': 321382,
#  'metaphysical store': 204468,
#  'store is': 303838,
#  'is closed': 166164,
#  'headin out': 142529,
#  'out to': 245853,
#  'to wish': 339024,
#  'wish txt': 373485,
#  'txt the': 349496,
#  'the celly': 318577,
#  'celly if': 62116,
#  'if goin': 157300,
#  'miss my': 206862,
#  'my bf': 215111,
#  'bf so': 44787,
#  'so much': 293186,
#  'yeah right': 382983,
#  'followfriday just': 111271,
#  'just because': 175536,
#  'because shes': 40673,
#  'shes good': 284750,
#  'good twitter': 128301,
#  'twitter people': 348593,
#  'trying to': 346039,
#  'to see': 338156,
#  'see on': 281219,
#  'on how': 239047,
#  'how many': 152814,
#  'many platforms': 198956,
#  'platforms can': 254930,
#  'can communicate': 58707,
#  'communicate with': 69501,
#  'with you': 375676,
#  'you youre': 386914,
#  'youre nice': 388796,
#  'nice person': 224166,
#  'person dont': 251628,
#  'dont lose': 88877,
#  'lose that': 192565,
#  'argh cant': 27363,
#  'cant find': 59684,
#  'find my': 107925,
#  'my phone': 217499,
#  'phone ive': 252356,
#  'ive called': 171998,
#  'called it': 58058,
#  'it thousand': 170000,
#  'thousand times': 331463,
#  'times and': 333855,
#  'and just': 20539,
#  'just realized': 176330,
#  'realized its': 267744,
#  'its on': 171336,
#  'on silent': 239743,
#  'silent great': 288251,
#  'great searching': 131492,
#  'searching high': 280391,
#  'high and': 147165,
#  'and low': 20802,
#  'low tomorrow': 194658,
#  'mixed up': 207731,
#  'up with': 352886,
#  'with my': 374931,
#  'my flights': 216116,
#  'flights bc': 110079,
#  'bc tried': 38090,
#  'tried to': 345108,
#  'to book': 335368,
#  'book flights': 48933,
#  'flights while': 110092,
#  'while on': 370267,
#  'on the': 239911,
#  'the phone': 322132,
#  'phone not': 252393,
#  'not smart': 229163,
#  'want really': 359698,
#  'really awesome': 267837,
#  'awesome vintage': 33487,
#  'vintage shirt': 357294,
#  'shirt that': 285180,
#  'that saw': 316491,
#  'saw its': 278075,
#  'its so': 171528,
#  'so pretty': 293298,
#  'jocorequests feel': 174018,
#  'feel fantastic': 105369,
#  'fantastic need': 103728,
#  'need to': 221124,
#  'to be': 335240,
#  'be reminded': 39399,
#  'reminded not': 270447,
#  'not to': 229287,
#  'to worry': 339062,
#  'worry about': 379120,
#  'about dead': 6144,
#  'dead lions': 80910,
#  'lions please': 188516,
#  'now if': 230345,
#  'if we': 157524,
#  'we could': 364100,
#  'could only': 72942,
#  'only put': 241756,
#  'put the': 262445,
#  'the together': 323878,
#  'together ftw': 340224,
#  'yeah well': 383077,
#  'well you': 367191,
#  'you just': 385901,
#  'just have': 175971,
#  'to ignore': 336708,
#  'ignore those': 157603,
#  'those people': 330793,
#  'people children': 250817,
#  'children cant': 64385,
#  'cant learn': 59743,
#  'learn without': 183882,
#  'without doing': 375782,
#  'doing good': 87919,
#  'good parent': 128044,
#  'parent knows': 248664,
#  'knows this': 180405,
#  'is not': 167234,
#  'not open': 228941,
#  'open to': 242500,
#  'to public': 337732,
#  'public but': 261699,
#  'but if': 55415,
#  'if you': 157548,
#  'you have': 385737,
#  'have the': 140842,
#  'the time': 323837,
#  'time and': 333178,
#  'and interested': 20417,
#  'interested please': 164189,
#  'please drop': 255731,
#  'drop by': 91405,
#  'why do': 371384,
#  'do get': 86533,
#  'get up': 123065,
#  'up in': 352409,
#  'in the': 162445,
#  'the early': 319451,
#  'early morning': 93100,
#  'morning on': 211164,
#  'on sunday': 239853,
#  'sunday to': 307799,
#  'to go': 336464,
#  'go work': 126116,
#  'work out': 377881,
#  'out right': 245714,
#  'right dont': 272682,
#  'dont want': 89048,
#  'want to': 359772,
#  'to miss': 337249,
#  'miss formula1': 206709,
#  'get it': 122601,
#  'on trex': 239989,
#  'trex httpblipfm7fbc2': 344957,
#  'and refuse': 21563,
#  'refuse to': 269603,
#  'to give': 336446,
#  'give up': 124751,
#  'up til': 352787,
#  'til realize': 332843,
#  'realize got': 267697,
#  'got sum': 129884,
#  'sum mass': 306949,
#  'mass solidiers': 199701,
#  'solidiers whod': 294265,
#  'whod do': 370950,
#  'do anything': 86363,
#  'anything stop': 24969,
#  'stop by': 303529,
#  'by their': 57155,
#  'their workplace': 325059,
#  'ill be': 157786,
#  'be sure': 39628,
#  'sure to': 308819,
#  'to wear': 338957,
#  'wear my': 364537,
#  'my party': 217446,
#  'party clothes': 249201,
#  'clothes and': 67101,
#  'and hair': 20200,
#  'just checked': 175639,
#  'checked and': 63540,
#  'and the': 22241,
#  'the story': 323526,
#  'story is': 304104,
#  'is still': 167807,
#  'still online': 302909,
#  'online on': 241294,
#  'the presstv': 322358,
#  'presstv site': 259328,
#  'oh im': 236109,
#  'im doing': 158527,
#  'doing well': 88096,
#  'well besides': 366661,
#  'besides uhm': 43659,
#  'uhm my': 350319,
#  'my kitty': 216785,
#  'kitty ran': 179415,
#  'ran awayyesterday': 266171,
#  'awayyesterday im': 33095,
#  'im worried': 159570,
#  'aww have': 33796,
#  'have missed': 140307,
#  'missed it': 207141,
#  'it knew': 169416,
#  'knew it': 179634,
#  'it was': 170112,
#  'was coming': 360546,
#  'coming up': 69252,
#  'up soon': 352705,
#  'soon on': 297120,
#  'on e4': 238760,
#  'e4 thought': 92772,
#  'thought it': 331304,
#  'was in': 360947,
#  'in few': 160976,
#  'few days': 106523,
#  'days time': 80533,
#  'wednesday must': 365216,
#  'must go': 214529,
#  'go to': 126044,
#  'to scholl': 338119,
#  'scholl im': 279245,
#  'im unhappy': 159491,
#  'unhappy about': 351288,
#  'about it': 6316,
#  'the air': 317677,
#  'air right': 11490,
#  'right now': 272794,
#  'now and': 229974,
#  'and is': 20431,
#  'is gonna': 166675,
#  'gonna pick': 127326,
#  'pick her': 253119,
#  'her up': 145217,
#  'up im': 352407,
#  'im quite': 159129,
#  'quite excited': 263265,
#  'excited though': 100882,
#  'though dont': 330984,
#  'dont see': 88960,
#  'see them': 281347,
#  'them til': 325419,
#  'til tomorrow': 332865,
#  'no baby': 225806,
#  'baby yet': 34811,
#  'yet due': 384506,
#  'due today': 92058,
#  'today waiting': 339859,
#  'waiting waiting': 358687,
#  'getting ready': 123603,
#  'ready for': 267314,
#  'for the': 114193,
#  'the wedding': 324398,
#  'wedding wish': 365171,
#  'wish boyfriend': 373337,
#  'boyfriend was': 50872,
#  'was here': 360887,
#  'hate it': 138935,
#  'has lovely': 138402,
#  'lovely hand': 194235,
#  'hand marks': 136649,
#  'marks over': 199424,
#  'over her': 246541,
#  'her back': 144610,
#  'back from': 35053,
#  'from trying': 118535,
#  'to apply': 335107,
#  'apply my': 25788,
#  'my own': 217398,
#  'own suncream': 247223,
#  'suncream need': 307618,
#  'need hot': 220919,
#  'hot suncream': 151638,
#  'suncream boy6': 307616,
#  'boy6 sleeps': 50803,
#  'sleeps til': 290922,
#  'til home': 332818,
#  'working on': 378431,
#  'on custom': 238649,
#  'custom cms': 76441,
#  'cms for': 67436,
#  'for skeedio': 113966,
#  'skeedio tiring': 289880,
#  'tiring but': 334535,
#  'but fun': 55301,
#  'ur welcomei': 354012,
#  'welcomei liked': 366591,
#  'liked the': 187841,
#  'the multiple': 321605,
#  'multiple acct': 213864,
#  'acct option': 7405,
#  'back in': 35119,
#  'the garage': 319999,
#  'garage working': 121279,
#  'working garbage': 378361,
#  'garbage day': 121283,
#  'day tomorrow': 80051,
#  'tomorrow woohoo': 341087,
#  'woohoo take': 377055,
#  'take it': 310749,
#  'it all': 168750,
#  'all away': 12351,
#  'httptwitpiccom6gizn braceless': 154406,
#  'braceless aw': 51076,
#  'aw it': 32552,
#  'it makes': 169484,
#  'makes me': 197589,
#  'me so': 202188,
#  'so happy': 292949,
#  'happy how': 137520,
#  'how sad': 152875,
#  'sad is': 275871,
#  'is that': 167934,
#  'that haha': 315809,
#  'haha xd': 135535,
#  'but ill': 55418,
#  'ill look': 157919,
#  'look when': 191949,
#  'when get': 369305,
#  'get on': 122740,
#  'on there': 239917,
#  'no no': 226539,
#  'no it': 226339,
#  'it isnt': 169375,
#  'isnt lol': 168469,
#  'lol although': 190396,
#  'although im': 14613,
#  'im sure': 159377,
#  'sure my': 308768,
#  'my dog': 215792,
#  'dog fred': 87572,
#  'fred would': 115829,
#  'would enjoy': 379571,
#  'enjoy that': 96709,
#  'im finally': 158623,
#  'finally back': 107500,
#  'own bed': 247097,
#  'bed listening': 41027,
#  'to hubby': 336684,
#  'hubby snore': 155044,
#  'snore what': 292360,
#  'what lovely': 368598,
#  'lovely sound': 194312,
#  'chinese as': 64679,
#  'as im': 28405,
#  'im feeling': 158610,
#  'feeling nervous': 105799,
#  'rapidshare is': 266396,
#  'is one': 167283,
#  'one tough': 240932,
#  'tough nut': 343521,
#  'nut to': 231354,
#  'to anyone': 335093,
#  'anyone for': 24740,
#  'for help': 112898,
#  'help here': 144260,
#  'maybe next': 200610,
#  'next time': 223661,
#  'time should': 333619,
#  'should try': 286456,
#  'try and': 345818,
#  'and catch': 19198,
#  'catch the': 61346,
#  'the ball': 317955,
#  'ball with': 36529,
#  'my glove': 216293,
#  'glove and': 125263,
#  'and not': 21133,
#  'not my': 228896,
#  'my other': 217390,
#  'other hand': 244229,
#  'hand ouch': 136664,
#  'freaking happy': 115762,
#  'happy that': 137635,
#  'that get': 315759,
#  'get to': 123024,
#  'to online': 337464,
#  'online studying': 241316,
#  'studying sejarah': 305159,
#  'sejarah awesome': 281885,
#  'awesome imissyouuu': 33289,
#  'imissyouuu lt3': 159794,
#  'lt3 ohh': 194887,
#  'ohh bladdy': 236417,
#  'bladdy need': 46854,
#  'to watch': 338943,
#  'watch movie': 362353,
#  'oh yeah': 236375,
#  'yeah she': 382999,
#  'she did': 284246,
#  'did kahit': 83859,
#  'kahit umuulan': 176933,
#  'umuulan the': 350709,
#  'the smile': 323318,
#  'smile on': 291798,
#  'on her': 238995,
#  'her face': 144760,
#  'face can': 102191,
#  'can still': 59064,
#  'still be': 302541,
#  'be seen': 39471,
#  'seen unfortunately': 281824,
#  'unfortunately didnt': 351197,
#  'didnt brought': 84095,
#  'brought my': 53070,
#  'my camera': 215349,
#  'woke up': 376195,
#  'up feeling': 352289,
#  'feeling miserably': 105789,
#  'miserably sick': 206545,
#  'aw thanks': 32593,
#  'thanks for': 314785,
#  'the hug': 320532,
#  'hug lol': 155125,
#  'lol hope': 190607,
#  'hope to': 150735,
#  'you guys': 385698,
#  'guys on': 133730,
#  'on monday': 239325,
#  'ha see': 134103,
#  'see know': 281138,
#  'know am': 179821,
#  'am right': 15573,
#  'right thia': 272885,
#  'thia time': 327882,
#  'time gonna': 333363,
#  'gonna miss': 127315,
#  'you till': 386682,
#  'till sunday': 333054,
#  'sunday haha': 307696,
#  'no camping': 225906,
#  'camping tonight': 58589,
#  'tonight now': 341456,
#  'yeahkris allen': 383141,
#  'allen is': 13154,
#  'is from': 166603,
#  'from where': 118618,
#  'where liveits': 369773,
#  'liveits pretty': 189598,
#  'pretty crazy': 259442,
#  'hee think': 143457,
#  'think ill': 328575,
#  'ill prefer': 157960,
#  'prefer genfriendship': 258943,
#  'genfriendship for': 121958,
#  'for this': 114206,
#  'this one': 329851,
#  'one get': 240572,
#  'get the': 122992,
#  'the creeps': 319012,
#  'creeps picturing': 75073,
#  'picturing spock': 253538,
#  'spock being': 299922,
#  'being anything': 42664,
#  'anything but': 24882,
#  'but immaculate': 55424,
#  'sneezing every': 292258,
#  'every 15sec': 99206,
#  '15sec my': 1293,
#  'my allergies': 214866,
#  'allergies are': 13183,
#  'on full': 238903,
#  'full force': 119422,
#  'force today': 114608,
#  'today not': 339644,
#  'not very': 229360,
#  'very happy': 356256,
#  'happy ephie': 137472,
#  'ephie at': 97334,
#  'at the': 31149,
#  'the moment': 321481,
#  'moment amp': 208574,
#  'amp dont': 16671,
#  'dont have': 88822,
#  'have my': 140341,
#  'my allergy': 214868,
#  'allergy meds': 13216,
#  'meds no': 203174,
#  'no bueno': 225888,
#  'blackberry troubles': 46816,
#  'troubles all': 345446,
#  'all over': 12799,
#  'over fortunately': 246514,
#  'fortunately enough': 115098,
#  'enough dont': 96928,
#  'have one': 140406,
#  'one my': 240733,
#  'my htc': 216572,
#  'htc touch': 153310,
#  'touch works': 343463,
#  'works fine': 378644,
#  'fine for': 108132,
#  'for almost': 112009,
#  'almost years': 13607,
#  'ahhh wawa': 11112,
#  'wawa miss': 363630,
#  'miss wawa': 207024,
#  'wawa could': 363628,
#  'could go': 72872,
#  'go for': 125680,
#  'for some': 114005,
#  'some diet': 294586,
#  'diet lemonade': 84584,
#  'lemonade tea': 185011,
#  'tea right': 312253,
#  'my shoulders': 218018,
#  'shoulders are': 286518,
#  'are sore': 26979,
#  'sore from': 297747,
#  'from carrying': 117614,
#  'carrying my': 60896,
#  'my bowling': 215223,
#  'bowling ball': 50534,
#  'ball in': 36504,
#  'my backpackstill': 214999,
#  'backpackstill need': 35503,
#  'to walk': 338926,
#  'walk to': 358886,
#  'to my': 337327,
#  'my car': 215366,
#  'car with': 60334,
#  'with it': 374565,
#  'it later': 169431,
#  'guys know': 133686,
#  'know of': 180077,
#  'of any': 232216,
#  'any pro': 24387,
#  'pro life': 260012,
#  'life youth': 186165,
#  'youth groups': 389091,
#  'groups in': 132316,
#  'the philippines': 322127,
#  'philippines let': 252128,
#  'let me': 185346,
#  'me know': 201727,
#  'know and': 179824,
#  'and hook': 20307,
#  'hook me': 150456,
#  'me up': 202387,
#  'with contact': 374084,
#  'httptwitpiccom2vzw6 look': 153965,
#  'look whos': 191952,
#  'whos half': 371250,
#  'half naked': 136382,
#  'naked again': 219540,
#  'haha okay': 135375,
#  'okay thanks': 237168,
#  'thanks guys': 314807,
#  'yeahits the': 383140,
#  'the power': 322316,
#  'power of': 258367,
#  'of youtube': 235024,
#  'just looked': 176118,
#  'looked back': 191982,
#  'back and': 34965,
#  'and wrote': 22722,
#  'wrote buon': 380770,
#  'buon gionro': 54385,
#  'gionro that': 124129,
#  'that was': 316903,
#  'was typo': 361641,
#  'typo honestly': 349712,
#  'honestly do': 150269,
#  'do know': 86629,
#  'know how': 179979,
#  'how to': 152932,
#  'to spell': 338394,
#  'spell giorno': 299438,
#  'giorno now': 124131,
#  'now thanks': 230692,
#  'thanks sue': 315011,
#  'sue enjoy': 306675,
#  'the holiday': 320434,
#  'holiday weekend': 149318,
#  'just woke': 176754,
#  'up layn': 352450,
#  'layn dwn': 183513,
#  'dwn next': 92610,
#  'next to': 223662,
#  'my mommy': 217140,
#  'mommy deciding': 208736,
#  'deciding if': 81468,
#  'we shall': 364354,
#  'shall get': 283728,
#  'up amp': 352071,
#  'amp start': 17401,
#  'start day': 301204,
#  'you made': 386036,
#  'made imafat13yroldg': 196534,
#  'imafat13yroldg day': 159658,
#  'day when': 80121,
#  'when you': 369622,
#  'you tweeted': 386737,
#  'tweeted at': 347368,
#  'at her': 30417,
#  'her thank': 145172,
#  'thank you': 314580,
#  'donny high': 88677,
#  'love sid': 193813,
#  'sid but': 287818,
#  'but im': 55420,
#  'worried he': 379055,
#  'he might': 142022,
#  'might already': 205050,
#  'already have': 13975,
#  'have girlfriend': 139990,
#  'girlfriend hope': 124394,
#  'hope he': 150630,
#  'he doesnt': 141904,
#  'doesnt but': 87383,
#  'if he': 157312,
#  'he does': 141903,
#  'does then': 87336,
#  'then hope': 325820,
#  'hope its': 150648,
#  'its not': 171310,
#  'not serious': 229123,
#  'serious or': 282729,
#  'or last': 243158,
#  'last long': 182287,
#  'michael you': 204776,
#  'you are': 385147,
#  'the only': 321894,
#  'only one': 241724,
#  'one that': 240906,
#  'that hasnt': 315831,
#  'hasnt replied': 138725,
#  'replied to': 270824,
#  'to me': 337164,
#  'me the': 202280,
#  'the sd': 323035,
#  'sd accoustic': 280226,
#  'accoustic show': 7395,
#  'show was': 286892,
#  'was awesome': 360389,
#  'awesome wish': 33508,
#  'wish coulda': 373354,
#  'coulda been': 73057,
#  'been there': 41945,
#  'to kill': 336892,
#  'kill me': 178623,
#  'me for': 201485,
#  'for tweeting': 114308,
#  'tweeting too': 347573,
#  'too much': 342219,
#  'much oh': 213495,
#  'oh well': 236336,
#  'well still': 367070,
#  'still cant': 302583,
#  'cant sleep': 59859,
#  'sleep and': 290389,
#  'and mcorgies': 20894,
#  'mcorgies is': 200958,
#  'is entertaining': 166448,
#  'entertaining me': 97132,
#  'me xd': 202493,
#  'xd its': 381320,
#  'its am': 170637,
#  'am weee': 15746,
#  'hey are': 146226,
#  'are you': 27158,
#  'you in': 385841,
#  'in wales': 162650,
#  'wales at': 358794,
#  'moment if': 208597,
#  'if so': 157457,
#  'so we': 293690,
#  'we should': 364356,
#  'should all': 286227,
#  'all go': 12575,
#  'go out': 125881,
#  'out sometime': 245766,
#  'sometime after': 296124,
#  'after these': 9400,
#  'these stupid': 327155,
#  'stupid exams': 305559,
#  'exams are': 100526,
#  'are over': 26797,
#  'over with': 246776,
#  'with though': 375480,
#  'ive been': 171985,
#  'been busy': 41463,
#  'busy writing': 54963,
#  'writing and': 380463,
#  'and watching': 22593,
#  'watching one': 363102,
#  'one flew': 240552,
#  'flew over': 109905,
#  'over the': 246706,
#  'the cuckoos': 319044,
#  'cuckoos nest': 75912,
#  'nest mean': 221728,
#  'mean didnt': 202609,
#  'didnt write': 84345,
#  'write that': 380394,
#  'that you': 316993,
#  'you know': 385929,
#  'know what': 180242,
#  'what mean': 368611,
#  'so nice': 293214,
#  'nice outside': 224155,
#  'might cry': 205069,
#  'cry farmyard': 75624,
#  'farmyard this': 103968,
#  'this weekend': 330262,
#  'weekend wont': 365981,
#  'wont be': 376726,
#  'be around': 38369,
#  'so my': 293198,
#  'my hair': 216405,
#  'hair is': 136133,
#  'is much': 167178,
#  'much lighter': 213433,
#  ...}

# %% [markdown]
# ### 1- The the top 10 words of each vectorizer
# ### 2- The most and least used word(s)

# %%
get_top_n = lambda pipeline, vectorized_data, n: sorted(zip(pipeline.named_steps['vectorizer'].get_feature_names_out(), 
                                                     vectorized_data.sum(axis=0).A1), 
                                                     key=lambda x: x[1], 
                                                      reverse=True)[:n]

get_all_data_sorted = lambda pipeline, vectorized_data: sorted(zip(pipeline.named_steps['vectorizer'].get_feature_names_out(), 
                                                     vectorized_data.sum(axis=0).A1), 
                                                     key=lambda x: x[1], 
                                                      reverse=True)

# %%
word_vocabulary = word_pipeline.fit_transform(x_train)
two_word_vocabulary = two_words_pipeline.fit_transform(x_train)

# Get top 10 words
top_words = get_top_n(word_pipeline, word_vocabulary, 10)
top_bigrams = get_top_n(two_words_pipeline, two_word_vocabulary, 10)

print(top_words)
print(top_bigrams)
# Out:
# [('to', 29539), ('the', 27486), ('my', 16672), ('and', 15757), ('you', 14386), ('is', 12499), ('it', 12322), ('for', 11519), ('in', 11481), ('of', 9583)]
# [('in the', 2391), ('going to', 2264), ('for the', 1810), ('on the', 1622), ('to be', 1581), ('to the', 1533), ('have to', 1523), ('to go', 1398), ('of the', 1306), ('to get', 1246)]

# %%
# Most used (can also be seen above) and the least used words and bigrams
all_words = get_all_data_sorted(word_pipeline, word_vocabulary)
all_bigrams = get_all_data_sorted(two_words_pipeline, two_word_vocabulary)

print(f"Most used word: {all_words[0]}, Least used word: {all_words[-1]}")
print(f"Most used bigram: {all_bigrams[0]}, Least used bigram: {all_bigrams[-1]}")
# Out:
# Most used word: ('to', 29539), Least used word: ('zzzzzzzzzzzzzzzz', 1)
# Most used bigram: ('in the', 2391), Least used bigram: ('zzzzzzzzzzzzzzzz if', 1)

# %% [markdown]
# ## Naive Bayes model full pipeline , fitting, evaluation, and tuning
#
# ### The full pipeline will conclude with a Naive Bayes classifier, which will be fitted and evaluated using classification metrics such as accuracy (suitable here due to the absence of class imbalance). It will then be tuned via its hyperparameters using GridSearchCV, which performs cross-validation by splitting the data into folds so that each fold is used for validation exactly once.

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV

# %%
pipeline = Pipeline([('text_preprocess', text_preprocessing_pipeline),
                          ('vectorizer', CountVectorizer()),
                          ('classifier', MultinomialNB())])

# %%
pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('text_preprocess',
#                  Pipeline(steps=[('remove_mentions',
#                                   FunctionTransformer(func=<function remove_mentions at 0x0000027A07723F60>)),
#                                  ('remove_punctuations',
#                                   FunctionTransformer(func=<function remove_punctuations at 0x0000027A07723EC0>)),
#                                  ('lowercase_strip',
#                                   FunctionTransformer(func=<function lower_case_remove_whitespace at 0x0000027A07723E20>)),
#                                  ('remove_ascii_characters',
#                                   FunctionTransformer(func=<function remove_non_ascii at 0x0000027A07723D80>))])),
#                 ('vectorizer', CountVectorizer()),
#                 ('classifier', MultinomialNB())])

# %%
#Training acuuracy score
training_accuracy = pipeline.score(x_train, y_train)
print(f"Training accuracy score: {training_accuracy}")
# Out:
# Training accuracy score: 0.8522874737512682

# %%
#Testing acuuracy score
testing_accuracy = pipeline.score(x_test, y_test)
print(f"Testing accuracy score: {testing_accuracy}")
# Out:
# Testing accuracy score: 0.761681930610335

# %%
#Looking the classification reports for both training and testing
y_pred_training = pipeline.predict(x_train)
report = classification_report(y_pred_training, y_train)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.86     44624
#            1       0.83      0.87      0.85     40142
#
#     accuracy                           0.85     84766
#    macro avg       0.85      0.85      0.85     84766
# weighted avg       0.85      0.85      0.85     84766

# %%
y_pred_testing = pipeline.predict(x_test)
report = classification_report(y_pred_testing, y_test)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.74      0.77      7957
#            1       0.73      0.78      0.75      7002
#
#     accuracy                           0.76     14959
#    macro avg       0.76      0.76      0.76     14959
# weighted avg       0.76      0.76      0.76     14959

# %% [markdown]
# ### The model achieves an accuracy of 85% on the training set and 76% on the test set. The classification report shows a consistent drop in precision, recall, and F1-score for both classes when evaluated on unseen data. These differences indicate potential overfitting, where the model performs better on the training data than on new data. Further hyperparmatrer tuning may help improve generalization.

# %%
# Hyperparamter tuning on the pipeline
search_space = {"vectorizer__ngram_range": [(1,1), (2,2), (3,3)],
                "classifier__alpha": [0.1, 1.0, 2.0, 3.0],
                "classifier__fit_prior": [True, False]}

# %%
grid = GridSearchCV(pipeline, param_grid = search_space, cv = 20, scoring = 'accuracy')

# %%
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=20,
#              estimator=Pipeline(steps=[('text_preprocess',
#                                         Pipeline(steps=[('remove_mentions',
#                                                          FunctionTransformer(func=<function remove_mentions at 0x0000027A07723F60>)),
#                                                         ('remove_punctuations',
#                                                          FunctionTransformer(func=<function remove_punctuations at 0x0000027A07723EC0>)),
#                                                         ('lowercase_strip',
#                                                          FunctionTransformer(func=<function lower_case_remove_whitespace at 0x0000027A07723E20>)),
#                                                         ('remove_ascii_characters',
#                                                          FunctionTransformer(func=<function remove_non_ascii at 0x0000027A07723D80>))])),
#                                        ('vectorizer', CountVectorizer()),
#                                        ('classifier', MultinomialNB())]),
#              param_grid={'classifier__alpha': [0.1, 1.0, 2.0, 3.0],
#                          'classifier__fit_prior': [True, False],
#                          'vectorizer__ngram_range': [(1, 1), (2, 2), (3, 3)]},
#              scoring='accuracy')

# %%
best_score = grid.best_score_
best_params = grid.best_params_

print(f"Best Score: {best_score}, Best Parameters: {best_params}")
# Out:
# Best Score: 0.7664156435873055, Best Parameters: {'classifier__alpha': 2.0, 'classifier__fit_prior': True, 'vectorizer__ngram_range': (1, 1)}

# %%
best_pipeline = grid.best_estimator_

# %%
#Training acuuracy score
training_accuracy = best_pipeline.score(x_train, y_train)
print(f"Training accuracy score: {training_accuracy}")
# Out:
# Training accuracy score: 0.8362668994644079

# %%
#Testing acuuracy score
testing_accuracy = best_pipeline.score(x_test, y_test)
print(f"Testing accuracy score: {testing_accuracy}")
# Out:
# Testing accuracy score: 0.7634200147068654

# %%
# Testing some random sentences (0: Negative , 1: Positive)
text = pd.Series("This game is absolute garbage, do not try it is not worth your time!")
prediction = pipeline.predict(text)
prediction
# Out:
# array([1], dtype=int64)

# %%
text = pd.Series("This game is an absolute beauty, must try and it is worth your time!")
prediction = pipeline.predict(text)
prediction
# Out:
# array([1], dtype=int64)

# %%
text = pd.Series("Trash game and it is absolute garbage, do not try it is not worth your time. I hate it !")
prediction = pipeline.predict(text)
prediction
# Out:
# array([0], dtype=int64)

# %% [markdown]
# ## Project Summary
#
# This project involves building a sentiment analysis model using the Naive Bayes algorithm to classify text reviews of games as either positive or negative. The workflow follows a typical machine learning pipeline from data ingestion to model evaluation and tuning.
#
# ---
#
# ### 1. Data Ingestion and Preprocessing
#
# * **Dataset** was imported from a CSV file.
# * Performed basic inspection to understand its structure and contents.
# * Checked missing values and removed duplicate entries to clean the dataset.
#
# ---
#
# ### 2. Exploratory Data Analysis (EDA)
#
# * Analyzed the most frequently used unigrams and bigrams in the text data.
# * Identified most and least used words and bigrams.
#
# ---
#
# ### 3. Text Preprocessing
#
# * Implemented functions to:
#
#   * Convert text to lowercase
#   * Remove mentions (e.g., `@username`)
#   * Remove special characters
# * Each function was unit tested for correctness.
# * Combined these steps into a preprocessing pipeline using `FunctionTransformer`.
#
# ---
#
# ### 4. Data Splitting
#
# * Split the dataset into training and testing sets.
# * Used a fixed `random_state` to ensure reproducibility.
#
# ---
#
# ### 5. Model Building and Initial Evaluation
#
# * Created a Scikit-learn pipeline with:
#
#   * A `CountVectorizer` for feature extraction
#   * A `MultinomialNB` classifier for training
# * **Initial results** before hyperparameter tuning:
#
#   * Training Accuracy: 85.23%
#   * Testing Accuracy: 76.17%
#
# ---
#
# ### 6. Hyperparameter Tuning
#
# * Conducted grid search over the following parameters:
#
#   * `vectorizer__ngram_range`: (1,1), (2,2), (3,3)
#   * `classifier__alpha`: \[0.1, 1.0, 2.0, 3.0, 4.0]
#   * `classifier__fit_prior`: \[True, False]
# * **Best parameters found**:
#
#   * `alpha`: 2.0
#   * `fit_prior`: True
#   * `ngram_range`: (1,1)
#
# ---
#
# ### 7. Final Model Performance
#
# * **After tuning**, results remained consistent:
#
#   * Training Accuracy: 83.63%
#   * Testing Accuracy: 76.34%
# * Minor overfitting was observed, but within a reasonable margin considering the simplicity of the model.
#
# ---
#
# ### 8. User Input Consideration
#
# * For prediction, user inputs need to be wrapped in a `pandas.Series` object to match the input format expected by the pipeline.
# * This approach is appropriate and efficient for backend integration in web applications.
#
# ---
#
# ### Notes
#
# * **Potential for Improvement**:
#   The current preprocessing pipeline expects `pandas.Series` input, which is fine for experimentation but suboptimal for production use. Refactoring the text preprocessing functions to handle raw string inputs would make the model more efficient and scalable in web or app backends.
#
# * **Model Performance & Overfitting Observation**:
#   Even after hyperparameter tuning, the training accuracy (\~83.6%) remained noticeably higher than the testing accuracy (\~76.3%). This suggests some degree of overfitting may still be present. The gap could be due to:
#
#   * **Dataset complexity**, including subtle linguistic patterns that the model may overfit.
#   * **Model simplicity**: Naive Bayes assumes conditional independence, which may not fully capture contextual relationships in text.
#   * **Limited expressiveness of features**: While n-grams help, they may not capture enough semantics to generalize well.
#
# Future improvements could involve richer features (like TF-IDF or embeddings) or trying other advanced architecture like transformers for better generalization.
